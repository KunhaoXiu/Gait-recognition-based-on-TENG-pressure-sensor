# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn import metrics
from data_preprocessing import preprocess_abnormal

# %%
xtrain_raw, xval, xtest, ytrain_raw, yval, ytest, scaler, le = preprocess_abnormal("datasets/abnormal")

# GridSearchCV 内部做交叉验证，不需要单独 val 集，合并 train+val 以充分利用数据
xtrain = np.concatenate([xtrain_raw, xval])
ytrain = np.concatenate([ytrain_raw, yval])
# Out:
# [Abnormal] classes：['Lhemiplegia', 'Parkinson', 'Rhemiplegia', 'normal'], train：2967, val：989, test：989

# %%
clf = DecisionTreeClassifier(random_state=42)

param_grid = {
    'criterion': ['gini'],
    'class_weight': ['balanced'],
    'max_depth': [5, 10, 20],
    'min_samples_leaf': [1, 2, 3, 5, 10]
}

grid = GridSearchCV(clf, param_grid, cv=10, scoring='accuracy', n_jobs=-1)
grid.fit(xtrain, ytrain)

print("Best params:", grid.best_params_)
print("Best CV acc:", grid.best_score_)

best_dt = grid.best_estimator_
y_pred_dt = best_dt.predict(xtest)

print("\nTest accuracy:", accuracy_score(ytest, y_pred_dt))
print(classification_report(ytest, y_pred_dt, target_names=list(le.classes_)))
# Out:
# Best params: {'class_weight': 'balanced', 'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1}
# Best CV acc: 0.9054654136299705
#
# Test accuracy: 0.9079878665318504
#               precision    recall  f1-score   support
#
#  Lhemiplegia       0.86      0.89      0.88       238
#    Parkinson       0.79      0.83      0.81       190
#  Rhemiplegia       0.98      0.98      0.98       265
#       normal       0.96      0.91      0.93       296
#
#     accuracy                           0.91       989
#    macro avg       0.90      0.90      0.90       989
# weighted avg       0.91      0.91      0.91       989

# %%
rf = RandomForestClassifier(random_state=42)

param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [5, 10, 20, 30],
    'min_samples_leaf': [1, 3, 5],
    'class_weight': ['balanced']
}

grid = GridSearchCV(rf, param_grid, cv=10, scoring='accuracy', n_jobs=-1)
grid.fit(xtrain, ytrain)

print("Best params:", grid.best_params_)
print("Best CV acc:", grid.best_score_)

best_rf = grid.best_estimator_
y_pred_rf = best_rf.predict(xtest)

print("\nTest accuracy:", accuracy_score(ytest, y_pred_rf))
print(classification_report(ytest, y_pred_rf, target_names=list(le.classes_)))
# Out:
# Best params: {'class_weight': 'balanced', 'max_depth': 20, 'min_samples_leaf': 1, 'n_estimators': 200}
# Best CV acc: 0.9370547244597878
#
# Test accuracy: 0.9474216380182002
#               precision    recall  f1-score   support
#
#  Lhemiplegia       0.95      0.94      0.94       238
#    Parkinson       0.87      0.90      0.88       190
#  Rhemiplegia       0.97      1.00      0.99       265
#       normal       0.97      0.94      0.96       296
#
#     accuracy                           0.95       989
#    macro avg       0.94      0.94      0.94       989
# weighted avg       0.95      0.95      0.95       989

# %%
labels = list(le.classes_)
matrix_rf = metrics.confusion_matrix(ytest, y_pred_rf)
matrix_dt = metrics.confusion_matrix(ytest, y_pred_dt)

# %%
plt.figure(figsize=(8, 6))
sns.set_theme(style="whitegrid", font='Times New Roman', font_scale=1.4)
sns.heatmap(matrix_rf,
            cmap="coolwarm",
            linecolor='white',
            linewidths=1,
            xticklabels=labels,
            yticklabels=labels,
            annot=True,
            fmt="d")
plt.title("RF Confusion Matrix")
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.savefig('./image/rf_NormalGait_CM.jpg', dpi=500, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.set_theme(style="whitegrid", font='Times New Roman', font_scale=1.4)
sns.heatmap(matrix_dt,
            cmap="coolwarm",
            linecolor='white',
            linewidths=1,
            xticklabels=labels,
            yticklabels=labels,
            annot=True,
            fmt="d")
plt.title("DT Confusion Matrix")
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.savefig('./image/dt_abNormalGait_CM.jpg', dpi=500, bbox_inches='tight')
plt.show()
